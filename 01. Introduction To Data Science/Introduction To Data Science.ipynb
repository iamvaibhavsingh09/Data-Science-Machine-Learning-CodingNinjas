# %% [markdown]
# # 1. Data Science

# %% [markdown]
# Data Science is the study from where we collect valuable data, what this data represents & how we turn this valuable resource in the creation of different strategies (Business), increases efficiencies.
#
# >Backed by Machine Learning & its algorithms for the analysis.

# %% [markdown]
# Data Science is the process of using data to find solutions to predict outcomes for the problem Statement.

# %% [markdown]
# Data Science is a multifaceted discipline of everything to do with data.

# %% [markdown]
# # 2. Work of Data Scientist

# %% [markdown]
# Understand the problem

# %% [markdown]
# Collect enough data (Files, Database, API & web scraping)
# >API[Programming Interface] (Google - Maps - User), Web Scrapping (means extract data from web.)

# %% [markdown]
# Process and clean data

# %% [markdown]
# Explore and visualize data

# %% [markdown]
# Analyse data using ML

# %% [markdown]
# Communicate the result

# %% [markdown]
# # 3. Data Science & Machine Learning (ML)

# %% [markdown]
# I. Data Science

# %% [markdown]
# ![machine_learning-1.png](attachment:machine_learning-1.png)

# %% [markdown]
# II. Machine Learning (ML)

# %% [markdown]
# Machine Learning make our machine capable of learning by their own.
# ie. without being explicitly programmed.

# %% [markdown]
# # 4. Libraries

# %% [markdown]
# #### Computation & Statistics

# %% [markdown]
# Numpy

# %% [markdown]
# Pandas

# %% [markdown]
# #### Visualization

# %% [markdown]
# Matplotlib

# %% [markdown]
# Plotly

# %% [markdown]
# Seaborn

# %% [markdown]
# #### Machine learning

# %% [markdown]
# Scikit-learn

# %% [markdown]
# Tensor flow

# %% [markdown]
# Keras

# %% [markdown]
# # Additional:
# > Difference between AI / ML / DL:

# %% [markdown]
# ###### Artificial Intelligence (or AI)
# Artificial Intelligence tries to make computers intelligent in order to minic the cognitive functions of humans.
# So it is a general field with a broad scope including: Computer Vision, Language Processing, Creativity, and Summarization.

# %% [markdown]
# ##### Machine Learning (or ML)
# Machine Learning is the branch of AI that covers the statistical part of Artificial Intelligence, which teaches the computer to solve problems by looking at hundreds or thousands of examples, learning from them, and then using that experience to solve the same problem in new situations.

# %% [markdown]
# ##### Deep Learning (or DL)
# Deep Learning is a very special field of Machine Learning where computers can actually learn and make intelligent decisions on their own.
# It involves a deeper level of automation in comparison with most machine learning algorithms.
