# %% [markdown]
# ### CREATE A LIST

# %%
li= []

# %%
li=[1,2,3]

# %%
type(li)
# Out:
# list

# %%
li = [1,2,'Parikh',3.4]

# %%
li
# Out:
# [1, 2, 'Parikh', 3.4]

# %% [markdown]
# ## ACCESS ELEMENTS IN LIST

# %%
li
# Out:
# [1, 2, 'Parikh', 3.4]

# %%
li[0]
# Out:
# 1

# %%
li[2]
# Out:
# 'Parikh'

# %%
li[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-eaafe881b5d5> in <module>
# ----> 1 li[4]
#
# IndexError: list index out of range

# %% [markdown]
# ### Changing ELEMENTS IN LIST

# %%
li
# Out:
# [1, 2, 'Parikh', 3.4]

# %%
li [0] = 5
li
# Out:
# [5, 2, 'Parikh', 3.4]

# %%
li = [5, 2, 'Parikh', 3.4]
li [3] = 'Rohan'
li
# Out:
# [5, 2, 'Parikh', 'Rohan']

# %%
li = [5, 2, 'Parikh', 'Rohan']
li [4] = 9
li
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-118-73f0774cd04f> in <module>
#       1 li = [5, 2, 'Parikh', 'Rohan']
# ----> 2 li [4] = 9
#       3 li
#
# IndexError: list assignment index out of range

# %% [markdown]
# ### SLICING OF THE LIST

# %%
li
# Out:
# [5, 2, 'Parikh', 'Rohan']

# %%
li[1:3]
# Out:
# [2, 'Parikh']

# %%
li[:]
# Out:
# [5, 2, 'Parikh', 'Rohan']

# %%
li[1:10]
# Out:
# [2, 'Parikh', 'Rohan']

# %%
li[1:]
# Out:
# [2, 'Parikh', 'Rohan']

# %% [markdown]
# # INSERT & APPEND ELEMENT IN THE LIST

# %%
li.append('Ankush')
li
# Out:
# [5, 2, 'Parikh', 'Rohan', 'Ankush']

# %%
li.insert(1,7)
li
# Out:
# [5, 7, 2, 'Parikh', 'Rohan', 'Ankush']

# %%
li.insert(6,10)
li
# Out:
# [5, 7, 2, 'Parikh', 'Rohan', 'Ankush', 10]

# %%
li.insert(9,'Karan')
li
# Out:
# [5, 7, 2, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan']

# %%
li
# Out:
# [5, 7, 2, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan']

# %%
li.append([9,10,11])
li
# Out:
# [5, 7, 2, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan', [9, 10, 11]]

# %%
li.extend([9,10,11])
li
# Out:
# [5, 7, 2, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan', [9, 10, 11], 9, 10, 11]

# %%
li.remove(2)
li
# Out:
# [5, 7, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan', [9, 10, 11], 9, 10, 11]

# %%
li.append(5)
li
# Out:
# [5, 7, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan', [9, 10, 11], 9, 10, 11, 5]

# %%
li.remove(5)

# %%
li
# Out:
# [7, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan', [9, 10, 11], 9, 10, 11, 5]

# %%
li.remove(6)
li
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-18b5c6a03e0a> in <module>
# ----> 1 li.remove(6)
#       2 li
#
# ValueError: list.remove(x): x not in list

# %%
li.pop()
li
# Out:
# [7, 'Parikh', 'Rohan', 'Ankush', 10, 'Karan', [9, 10, 11], 9, 10, 11]

# %%
li.pop()
# Out:
# 11

# %%
li.pop(2)
# Out:
# 'Rohan'

# %%
li
# Out:
# [7, 'Parikh', 'Ankush', 10, 'Karan', [9, 10, 11], 9, 10]

# %%
len(li)
# Out:
# 8
